# %%
# Import required libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = pd.read_csv(r"C:\Users\Monisha H L\Downloads\iris (2).csv")

# Separate features and target
X = data.drop("species", axis=1)   # assuming 'species' is the target column
y = data["species"]

# Split dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 1: Build Random Forest with default n_estimators=10
rf_default = RandomForestClassifier(n_estimators=10, random_state=42)
rf_default.fit(X_train, y_train)
y_pred_default = rf_default.predict(X_test)
default_score = accuracy_score(y_test, y_pred_default)

print(f"Default RF (10 trees) Accuracy: {default_score:.4f}")

# Step 2: Fine-tune number of trees
best_score = 0
best_n = 0
for n in range(10, 201, 10):  # test from 10 to 200 trees in steps of 10
    rf = RandomForestClassifier(n_estimators=n, random_state=42)
    rf.fit(X_train, y_train)
    y_pred = rf.predict(X_test)
    score = accuracy_score(y_test, y_pred)
    
    print(f"n_estimators={n}, Accuracy={score:.4f}")
    
    if score > best_score:
        best_score = score
        best_n = n

print(f"\nBest Accuracy: {best_score:.4f} achieved with {best_n} trees")
# Out:
# Default RF (10 trees) Accuracy: 1.0000
# n_estimators=10, Accuracy=1.0000
# n_estimators=20, Accuracy=1.0000
# n_estimators=30, Accuracy=1.0000
# n_estimators=40, Accuracy=1.0000
# n_estimators=50, Accuracy=1.0000
# n_estimators=60, Accuracy=1.0000
# n_estimators=70, Accuracy=1.0000
# n_estimators=80, Accuracy=1.0000
# n_estimators=90, Accuracy=1.0000
# n_estimators=100, Accuracy=1.0000
# n_estimators=110, Accuracy=1.0000
# n_estimators=120, Accuracy=1.0000
# n_estimators=130, Accuracy=1.0000
# n_estimators=140, Accuracy=1.0000
# n_estimators=150, Accuracy=1.0000
# n_estimators=160, Accuracy=1.0000
# n_estimators=170, Accuracy=1.0000
# n_estimators=180, Accuracy=1.0000
# n_estimators=190, Accuracy=1.0000
# n_estimators=200, Accuracy=1.0000
#
# Best Accuracy: 1.0000 achieved with 10 trees
